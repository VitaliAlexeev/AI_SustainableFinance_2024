# %% [markdown]
# # Mapping Sustainability Data

# %%
#!pip install geopy
#!pip install folium

# %%
import yfinance as yf
import pandas as pd
from geopy.geocoders import Nominatim
import folium   # library to plot the coordinates on an interactive map
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Getting coordinates
#
# Getting Company Headquarters Coordinates: You can use the `geopy` library to get the coordinates of company headquarters based on the location information provided by **Yahoo Finance**. The info object from Yahoo Finance often contains a 'city' and 'country' key, which you can use to determine the coordinates using a geocoding API like OpenStreetMap's Nominatim.
#
# Try it in a simple code example below:

# %%
geolocator = Nominatim(user_agent="company_locator")
location=geolocator.geocode("Sydney, Australia")
lat = location.latitude
lon = location.longitude
print(f"Latitude: {lat}; Longitude: {lon}")
# Out:
# Latitude: -33.8698439; Longitude: 151.2082848

# %% [markdown]
# ## Select the companies for analysis

# %%
# Option A: Specify a list of tickers:
tickers = ['DELL', 'ABNB', 'PANW', 'BKNG', 'UBER', 'IBM', 'SCCO', 'ADBE',
          'NFLX', 'SAP', 'TXN', 'ORCL', 'TTD', 'MU', 'PYPL', 'INTC',
          'GOOG', 'MSFT', 'NVDA', 'AMZN', 'META', 'TSLA', 'AAPL', 'AMD', 'CRM',
          'BA', 'AA', 'MMM', 'AMGN', 'CAT', 'CVX', 'CSCO', 'KO', 'DOW', 'DIS']

# %%
# Option B: Specify a list of tickers:
# Open the file in read mode
#with open('data/stock_symbol_list_SP500_B.txt', 'r') as file:
#    # Read each line and strip any leading/trailing whitespace characters (like newlines)
#    tickers = [line.strip() for line in file]

# %% [markdown]
# ## Download company data

# %%
# Initialize an empty list to store data
data = []

# Initialize geolocator
geolocator = Nominatim(user_agent="company_locator")

# %%
# Loop through each ticker and extract the required information
for ticker in tickers:
    stock = yf.Ticker(ticker)
   
    print(ticker)
    
    # Initialize ESG scores to None by default
    environment_score = social_score = governance_score = None
    city = country = None
    lat = lon = None
    
    try:
        # Extract the sustainability scores 
        sustainability = stock.sustainability
        
        # If sustainability data is available, extract the relevant ESG scores
        environment_score = sustainability.loc['environmentScore'].values[0]
        social_score = sustainability.loc['socialScore'].values[0]
        governance_score = sustainability.loc['governanceScore'].values[0]
    except KeyError:
        # If the ESG scores are not available, they remain as None
        print(f"Sustainability data is currently not available for {ticker}.")
        
    # Extract other relevant information
    info = stock.info
    market_cap = info.get('marketCap')
    industry_sector = info.get('sector')
    city = info.get('city')
    country = info.get('country')
    
    # Get coordinates using the city and country
    if city and country:
        location = geolocator.geocode(f"{city}, {country}")
        if location:
            lat = location.latitude
            lon = location.longitude
        else:
            print(f"Coordinates not found for {ticker} in {city}, {country}")
    
    # Append the data to the list
    data.append([ticker, environment_score, social_score, governance_score, market_cap, industry_sector, city, country, lat, lon])

# Convert the list to a pandas DataFrame
df = pd.DataFrame(data, columns=['Ticker', 'Environment Score', 'Social Score', 'Governance Score', 'Market Cap', 'Industry Sector', 'City', 'Country', 'Latitude', 'Longitude'])
# Out:
# DELL
# ABNB
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ABNB?modules=esgScores&corsDomain=finance.yahoo.com&formatted=false&symbol=ABNB&crumb=kK3RGC63QKE
# Sustainability data is currently not available for ABNB.
# PANW
# BKNG
# UBER
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/UBER?modules=esgScores&corsDomain=finance.yahoo.com&formatted=false&symbol=UBER&crumb=kK3RGC63QKE
# Sustainability data is currently not available for UBER.
# IBM
# SCCO
# ADBE
# NFLX
# SAP
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/SAP?modules=esgScores&corsDomain=finance.yahoo.com&formatted=false&symbol=SAP&crumb=kK3RGC63QKE
# Sustainability data is currently not available for SAP.
# TXN
# ORCL
# TTD
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/TTD?modules=esgScores&corsDomain=finance.yahoo.com&formatted=false&symbol=TTD&crumb=kK3RGC63QKE
# Sustainability data is currently not available for TTD.
# MU
# PYPL
# INTC
# GOOG
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/GOOG?modules=esgScores&corsDomain=finance.yahoo.com&formatted=false&symbol=GOOG&crumb=kK3RGC63QKE
# Sustainability data is currently not available for GOOG.
# MSFT
# NVDA
# AMZN
# META
# TSLA
# AAPL
# AMD
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AMD?modules=esgScores&corsDomain=finance.yahoo.com&formatted=false&symbol=AMD&crumb=kK3RGC63QKE
# Sustainability data is currently not available for AMD.
# CRM
# BA
# AA
# MMM
# AMGN
# CAT
# CVX
# CSCO
# KO
# DOW
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/DOW?modules=esgScores&corsDomain=finance.yahoo.com&formatted=false&symbol=DOW&crumb=kK3RGC63QKE
# Sustainability data is currently not available for DOW.
# DIS

# %%
# Display the DataFrame
df
# Out:
#    Ticker  Environment Score  Social Score  Governance Score     Market Cap  \
# 0    DELL               0.71          8.41              7.54    80282607616
# 1    ABNB                NaN           NaN               NaN    74467803136
# 2    PANW               0.70          7.62              5.60   112950640640
# 3    BKNG               0.98         10.13              8.13   131837722624
# 4    UBER                NaN           NaN               NaN   152276140032
# 5     IBM               1.78          6.22              6.14   197853380608
# 6    SCCO              12.89          8.74              5.87    77524353024
# 7    ADBE               1.94          5.99              5.15   238048149504
# 8    NFLX               0.09          7.31              9.01   299153752064
# 9     SAP                NaN           NaN               NaN   259284844544
# 10    TXN               7.76          5.96              6.93   182545285120
# 11   ORCL               0.50          7.79              5.60   448980287488
# 12    TTD                NaN           NaN               NaN    52136759296
# 13     MU               7.23          5.46              5.49   101148377088
# 14   PYPL               2.83          9.19              5.75    71665328128
# 15   INTC               4.93          7.32              6.62    84066156544
# 16   GOOG                NaN           NaN               NaN  1943421583360
# 17   MSFT               1.46          7.53              6.07  3200592642048
# 18   NVDA               2.30          4.95              6.34  2921523052544
# 19   AMZN               6.00         15.39              9.22  1957324390400
# 20   META               2.71         21.09             10.29  1327194046464
# 21   TSLA               3.31         14.08              7.85   735693570048
# 22   AAPL               0.46          7.39              9.37  3382912221184
# 23    AMD                NaN           NaN               NaN   246510682112
# 24    CRM               2.01          7.48              5.39   243368919040
# 25     BA               8.84         22.48              8.29    96605282304
# 26     AA              13.78          5.92              4.26     8401217024
# 27    MMM              17.22         13.59              6.54    73162956800
# 28   AMGN               0.73         13.48              7.75   178635046912
# 29    CAT              10.43         17.69              8.06   167440121856
# 30    CVX              17.01          9.18             10.42   255171985408
# 31   CSCO               0.45          6.90              6.51   198738345984
# 32     KO               7.23          9.54              4.86   307767836672
# 33    DOW                NaN           NaN               NaN    35151192064
# 34    DIS               0.04          8.96              6.71   164220583936
#
#            Industry Sector           City        Country   Latitude  \
# 0               Technology     Round Rock  United States  30.508592
# 1        Consumer Cyclical  San Francisco  United States  37.779259
# 2               Technology    Santa Clara  United States  37.233325
# 3        Consumer Cyclical        Norwalk  United States  41.117597
# 4               Technology  San Francisco  United States  37.779259
# 5               Technology         Armonk  United States  41.126485
# 6          Basic Materials        Phoenix  United States  33.448437
# 7               Technology       San Jose  United States  37.336166
# 8   Communication Services      Los Gatos  United States  37.226611
# 9               Technology       Walldorf        Germany  49.303813
# 10              Technology         Dallas  United States  32.776272
# 11              Technology         Austin  United States  30.271129
# 12              Technology        Ventura  United States  34.445825
# 13              Technology          Boise  United States  43.616616
# 14      Financial Services       San Jose  United States  37.336166
# 15              Technology    Santa Clara  United States  37.233325
# 16  Communication Services  Mountain View  United States  37.389389
# 17              Technology        Redmond  United States  47.669414
# 18              Technology    Santa Clara  United States  37.233325
# 19       Consumer Cyclical        Seattle  United States  47.603832
# 20  Communication Services     Menlo Park  United States  37.451967
# 21       Consumer Cyclical         Austin  United States  30.271129
# 22              Technology      Cupertino  United States  37.322893
# 23              Technology    Santa Clara  United States  37.233325
# 24              Technology  San Francisco  United States  37.779259
# 25             Industrials      Arlington  United States  32.735582
# 26         Basic Materials     Pittsburgh  United States  40.441694
# 27             Industrials     Saint Paul  United States  44.949749
# 28              Healthcare  Thousand Oaks  United States  34.170561
# 29             Industrials         Irving  United States  32.829518
# 30                  Energy      San Ramon  United States  37.764802
# 31              Technology       San Jose  United States  37.336166
# 32      Consumer Defensive        Atlanta  United States  33.748992
# 33         Basic Materials        Midland  United States  31.836880
# 34  Communication Services        Burbank  United States  34.181209
#
#      Longitude
# 0   -97.678806
# 1  -122.419329
# 2  -121.684635
# 3   -73.407897
# 4  -122.419329
# 5   -73.713978
# 6  -112.074141
# 7  -121.890591
# 8  -121.974680
# 9     8.643352
# 10  -96.796856
# 11  -97.743700
# 12 -119.077936
# 13 -116.200886
# 14 -121.890591
# 15 -121.684635
# 16 -122.083210
# 17 -122.123877
# 18 -121.684635
# 19 -122.330062
# 20 -122.177992
# 21  -97.743700
# 22 -122.032290
# 23 -121.684635
# 24 -122.419329
# 25  -97.107119
# 26  -79.990086
# 27  -93.093103
# 28 -118.837594
# 29  -96.944218
# 30 -121.954439
# 31 -121.890591
# 32  -84.390264
# 33 -102.010377
# 34 -118.307201

# %% [markdown]
# ## Plot an interactive map

# %% [markdown]
# ### Map of company locations

# %%
# Plot the coordinates on a map using folium
# Initialize a map centered at a global level
company_map = folium.Map(location=[20, 0], zoom_start=2)

# Add a marker for each company
for index, row in df.iterrows():
    if pd.notna(row['Latitude']) and pd.notna(row['Longitude']):
        folium.Marker(
            location=[row['Latitude'], row['Longitude']],
            popup=f"{row['Ticker']} ({row['City']}, {row['Country']})",
            tooltip=row['Ticker']
        ).add_to(company_map)

# Save the map to an HTML file and display it
company_map.save("company_map.html")
company_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cab2a4f9c0c16700cff6bf5edb78e97d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cab2a4f9c0c16700cff6bf5edb78e97d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cab2a4f9c0c16700cff6bf5edb78e97d = L.map(
#                 &quot;map_cab2a4f9c0c16700cff6bf5edb78e97d&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e525bea894200be6e7d210ba49cebe61 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e525bea894200be6e7d210ba49cebe61.addTo(map_cab2a4f9c0c16700cff6bf5edb78e97d);
#
#
#             var marker_b3b483965afd98bfb37f972204ad3d4d = L.marker(
#                 [30.5085915, -97.6788056],
#                 {}
#             ).addTo(map_cab2a4f9c0c16700cff6bf5edb78e97d);
#
#
#         var popup_8d6c9f599f0c0aced7ed74d4c6e0a61d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_af0f2783c36b7ce416b02710c6a6aff2 = $(`&lt;div id=&quot;html_af0f2783c36b7ce416b02710c6a6aff2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DELL (Round Rock, United States)&lt;/div&gt;`)[0];
#                 popup_8d6c9f599f0c0aced7ed74d4c6e0a61d.setContent(html_af0f2783c36b7ce416b02710c6a6aff2);
#
#
#
#         marker_b3b483965afd98bfb37f972204ad3d4d.bindPopup(popup_8d6c9f599f0c0aced7ed74d4c6e0a61d)
#         ;
#
#
#
#
#             marker_b3b483965afd98bfb37f972204ad3d4d.bindTooltip(
#                 `&lt;div&gt;
#                      DELL
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_dab391fad4e627ee5509dad9367b63e2 = L.marker(
#                 [37.7792588, -122.4193286],
#                 {}
#             ).addTo(map_cab2a4f9c0c16700cff6bf5edb78e97d);
#
#
#         var popup_1da9cec6df8aa21357fc80980a4e6e3d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4e2e50d820e1fa04bf91bad3868fcfd9 = $(`&lt;div id=&quot;html_4e2e50d820e1fa04bf91bad3868fcfd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ABNB (San Francisco, United States)&lt;/div&gt;`)[0];
#                 popup_1da9cec6df8aa21357fc80980a4e6e3d.setContent(html_4e2e50d820e1fa04bf91bad3868fcfd9);
#
#
#
#         marker_dab391fad4e627ee5509dad9367b63e2.bindPopup(popup_1da9cec6df8aa21357fc80980a4e6e3d)
#         ;
#
#
#
#
#             marker_dab391fad4e627ee5509dad9367b63e2.bindTooltip(
#                 `&lt;div&gt;
#                      ABNB
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_488cf7d36db668418ad11c03c78e6b57 = L.marker(
#                 [37.2333253, -121.6846349],
#                 {}
#             ).addTo(map_cab2a4f9c0c16700cff6bf5edb78e97d);
#
#
#         var popup_0358881a6ff4e2ab8adbd54185566bbd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3b79b04e82aa260b7d8b1740815073be = $(`&lt;div id=&quot;html_3b79b04e82aa260b7d8b1740815073be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;PANW (Santa Clara, United States)&lt;/div&gt;`)[0];
#                 popup_0358881a6ff4e2ab8adbd54185566bbd.setContent(html_3b79b04e82aa260b7d8b1740815073be);
#
#
#
#         marker_488cf7d36db668418ad11c03c78e6b57.bindPopup(popup_0358881a6ff4e2ab8adbd54185566bbd)
#         ;
#
#
#
#
#             marker_488cf7d36db668418ad11c03c78e6b57.bindTooltip(
#                 `&lt;div&gt;
#                      PANW
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_56978d3a49d4965fbd8f4b96c50ce3f3 = L.marker(
#                 [41.1175966, -73.4078968],
#                 {}
#             ).addTo(map_cab2a4f9c0c16700cff6bf5edb78e97d);
#
#
#         var popup_52e95ecaf50ecaaa8743458e8d35b9d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1d2ed12c67c2e67a9dc29572cd34ce26 = $(`&lt;div id=&quot;html_1d2ed12c67c2e67a9dc29572cd34ce26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BKNG (Norwalk, United States)&lt;/div&gt;`)[0];
#                 popup_52e95ecaf50ecaaa8743458e8d35b9d8.setContent(html_1d2ed12c67c2e67a9dc29572cd34ce26);
#
#
#
#         marker_56978d3a49d4965fbd8f4b96c50ce3f3.bindPopup(popup_52e95ecaf50ecaaa8743458e8d35b9d8)
#         ;
#
#
#
#
#             marker_56978d3a49d4965fbd8f4b96c50ce3f3.bindTooltip(
#                 `&lt;div&gt;
#                      BKNG
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );

# %% [markdown]
# ### Map companies's market capitalization

# %%
# Normalize the market capitalization using Min-Max Scaling
scaler = MinMaxScaler(feature_range=(5, 50))  # Bubble size range between 5 and 50
df['Scaled Market Cap'] = scaler.fit_transform(df[['Market Cap']])

# Display the DataFrame
display(df)
# Out:
#    Ticker  Environment Score  Social Score  Governance Score     Market Cap  \
# 0    DELL               0.71          8.41              7.54    80282607616
# 1    ABNB                NaN           NaN               NaN    74467803136
# 2    PANW               0.70          7.62              5.60   112950640640
# 3    BKNG               0.98         10.13              8.13   131837722624
# 4    UBER                NaN           NaN               NaN   152276140032
# 5     IBM               1.78          6.22              6.14   197853380608
# 6    SCCO              12.89          8.74              5.87    77524353024
# 7    ADBE               1.94          5.99              5.15   238048149504
# 8    NFLX               0.09          7.31              9.01   299153752064
# 9     SAP                NaN           NaN               NaN   259284844544
# 10    TXN               7.76          5.96              6.93   182545285120
# 11   ORCL               0.50          7.79              5.60   448980287488
# 12    TTD                NaN           NaN               NaN    52136759296
# 13     MU               7.23          5.46              5.49   101148377088
# 14   PYPL               2.83          9.19              5.75    71665328128
# 15   INTC               4.93          7.32              6.62    84066156544
# 16   GOOG                NaN           NaN               NaN  1943421583360
# 17   MSFT               1.46          7.53              6.07  3200592642048
# 18   NVDA               2.30          4.95              6.34  2921523052544
# 19   AMZN               6.00         15.39              9.22  1957324390400
# 20   META               2.71         21.09             10.29  1327194046464
# 21   TSLA               3.31         14.08              7.85   735693570048
# 22   AAPL               0.46          7.39              9.37  3382912221184
# 23    AMD                NaN           NaN               NaN   246510682112
# 24    CRM               2.01          7.48              5.39   243368919040
# 25     BA               8.84         22.48              8.29    96605282304
# 26     AA              13.78          5.92              4.26     8401217024
# 27    MMM              17.22         13.59              6.54    73162956800
# 28   AMGN               0.73         13.48              7.75   178635046912
# 29    CAT              10.43         17.69              8.06   167440121856
# 30    CVX              17.01          9.18             10.42   255171985408
# 31   CSCO               0.45          6.90              6.51   198738345984
# 32     KO               7.23          9.54              4.86   307767836672
# 33    DOW                NaN           NaN               NaN    35151192064
# 34    DIS               0.04          8.96              6.71   164220583936
#
#            Industry Sector           City        Country   Latitude  \
# 0               Technology     Round Rock  United States  30.508592
# 1        Consumer Cyclical  San Francisco  United States  37.779259
# 2               Technology    Santa Clara  United States  37.233325
# 3        Consumer Cyclical        Norwalk  United States  41.117597
# 4               Technology  San Francisco  United States  37.779259
# 5               Technology         Armonk  United States  41.126485
# 6          Basic Materials        Phoenix  United States  33.448437
# 7               Technology       San Jose  United States  37.336166
# 8   Communication Services      Los Gatos  United States  37.226611
# 9               Technology       Walldorf        Germany  49.303813
# 10              Technology         Dallas  United States  32.776272
# 11              Technology         Austin  United States  30.271129
# 12              Technology        Ventura  United States  34.445825
# 13              Technology          Boise  United States  43.616616
# 14      Financial Services       San Jose  United States  37.336166
# 15              Technology    Santa Clara  United States  37.233325
# 16  Communication Services  Mountain View  United States  37.389389
# 17              Technology        Redmond  United States  47.669414
# 18              Technology    Santa Clara  United States  37.233325
# 19       Consumer Cyclical        Seattle  United States  47.603832
# 20  Communication Services     Menlo Park  United States  37.451967
# 21       Consumer Cyclical         Austin  United States  30.271129
# 22              Technology      Cupertino  United States  37.322893
# 23              Technology    Santa Clara  United States  37.233325
# 24              Technology  San Francisco  United States  37.779259
# 25             Industrials      Arlington  United States  32.735582
# 26         Basic Materials     Pittsburgh  United States  40.441694
# 27             Industrials     Saint Paul  United States  44.949749
# 28              Healthcare  Thousand Oaks  United States  34.170561
# 29             Industrials         Irving  United States  32.829518
# 30                  Energy      San Ramon  United States  37.764802
# 31              Technology       San Jose  United States  37.336166
# 32      Consumer Defensive        Atlanta  United States  33.748992
# 33         Basic Materials        Midland  United States  31.836880
# 34  Communication Services        Burbank  United States  34.181209
#
#      Longitude  Scaled Market Cap
# 0   -97.678806           5.958557
# 1  -122.419329           5.881015
# 2  -121.684635           6.394194
# 3   -73.407897           6.646059
# 4  -122.419329           6.918610
# 5   -73.713978           7.526395
# 6  -112.074141           5.921775
# 7  -121.890591           8.062403
# 8  -121.974680           8.877262
# 9     8.643352           8.345600
# 10  -96.796856           7.322257
# 11  -97.743700          10.875239
# 12 -119.077936           5.583225
# 13 -116.200886           6.236808
# 14 -121.890591           5.843644
# 15 -121.684635           6.009012
# 16 -122.083210          30.804010
# 17 -122.123877          47.568720
# 18 -121.684635          43.847253
# 19 -122.330062          30.989408
# 20 -122.177992          22.586452
# 21  -97.743700          14.698637
# 22 -122.032290          50.000000
# 23 -121.684635           8.175253
# 24 -122.419329           8.133357
# 25  -97.107119           6.176225
# 26  -79.990086           5.000000
# 27  -93.093103           5.863615
# 28 -118.837594           7.270113
# 29  -96.944218           7.120826
# 30 -121.954439           8.290754
# 31 -121.890591           7.538196
# 32  -84.390264           8.992133
# 33 -102.010377           5.356718
# 34 -118.307201           7.077893

# %%
# Initialize a map centered globally
company_map = folium.Map(location=[20, 0], zoom_start=2)

# Add a marker with bubbles scaled by market capitalization
for index, row in df.iterrows():
    if pd.notna(row['Latitude']) and pd.notna(row['Market Cap']):
        folium.CircleMarker(
            location=[row['Latitude'], row['Longitude']],
            radius=row['Scaled Market Cap'],  # Scaled bubble size
            color='blue',
            fill=True,
            fill_opacity=0.5,  # Adjust transparency as needed
            popup=folium.Popup(f"{row['Ticker']} - Market Cap: ${row['Market Cap']:,}")
        ).add_to(company_map)

# Save the map to an HTML file and display it
company_map.save("company_map_market_cap.html")
company_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d2a54451c08513dfa34902e3c25b59aa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d2a54451c08513dfa34902e3c25b59aa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d2a54451c08513dfa34902e3c25b59aa = L.map(
#                 &quot;map_d2a54451c08513dfa34902e3c25b59aa&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7fb1b42866f4b336e7c48bb7f82faa50 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7fb1b42866f4b336e7c48bb7f82faa50.addTo(map_d2a54451c08513dfa34902e3c25b59aa);
#
#
#             var circle_marker_d03248642a9c4b685daecf9ffd7be422 = L.circleMarker(
#                 [30.5085915, -97.6788056],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5.958557424365308, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d2a54451c08513dfa34902e3c25b59aa);
#
#
#         var popup_669c93e4beb609d664c2d9a41cd842a6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_36d304f577771812866265ddd58e1e1d = $(`&lt;div id=&quot;html_36d304f577771812866265ddd58e1e1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DELL - Market Cap: $80,282,607,616&lt;/div&gt;`)[0];
#                 popup_669c93e4beb609d664c2d9a41cd842a6.setContent(html_36d304f577771812866265ddd58e1e1d);
#
#
#
#         circle_marker_d03248642a9c4b685daecf9ffd7be422.bindPopup(popup_669c93e4beb609d664c2d9a41cd842a6)
#         ;
#
#
#
#
#             var circle_marker_201480a500a6ace165b81817566f39b8 = L.circleMarker(
#                 [37.7792588, -122.4193286],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5.881015463092275, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d2a54451c08513dfa34902e3c25b59aa);
#
#
#         var popup_5a19f47fbe5ec584b4d15bcd3d32f6e4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_01efe4320c92f93ba6a477885f8d2609 = $(`&lt;div id=&quot;html_01efe4320c92f93ba6a477885f8d2609&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ABNB - Market Cap: $74,467,803,136&lt;/div&gt;`)[0];
#                 popup_5a19f47fbe5ec584b4d15bcd3d32f6e4.setContent(html_01efe4320c92f93ba6a477885f8d2609);
#
#
#
#         circle_marker_201480a500a6ace165b81817566f39b8.bindPopup(popup_5a19f47fbe5ec584b4d15bcd3d32f6e4)
#         ;
#
#
#
#
#             var circle_marker_b2494000b39570c26211d9c47414c0f5 = L.circleMarker(
#                 [37.2333253, -121.6846349],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6.394194316426929, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d2a54451c08513dfa34902e3c25b59aa);
#
#
#         var popup_5ae42d9d714c2aee335c166dbe884e7a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_829ba705486a41b3537adbdd415fe716 = $(`&lt;div id=&quot;html_829ba705486a41b3537adbdd415fe716&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;PANW - Market Cap: $112,950,640,640&lt;/div&gt;`)[0];
#                 popup_5ae42d9d714c2aee335c166dbe884e7a.setContent(html_829ba705486a41b3537adbdd415fe716);
#
#
#
#         circle_marker_b2494000b39570c26211d9c47414c0f5.bindPopup(popup_5ae42d9d714c2aee335c166dbe884e7a)
#         ;
#
#
#
#
#             var circle_marker_16ee24a79e335ac959f637b632b7824d = L.circleMarker(
#                 [41.1175966, -73.4078968],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &q

# %% [markdown]
# ### Map companies' ESG risk profiles

# %%
# Initialize a map centered globally
company_map = folium.Map(location=[20, 0], zoom_start=2)

# Add layers for Environmental, Social, and Governance Scores
esg_layers = {
    'Environment Score': folium.FeatureGroup(name='Environment Score', overlay=True),
    'Social Score': folium.FeatureGroup(name='Social Score', overlay=True),
    'Governance Score': folium.FeatureGroup(name='Governance Score', overlay=True)
}

# Function to add circle marker based on ESG score
def add_esg_layer(esg_layer, score_column, color, popup_label):
    for index, row in df.iterrows():
        if pd.notna(row['Latitude']) and pd.notna(row[score_column]):
            folium.CircleMarker(
                location=[row['Latitude'], row['Longitude']],
                radius=row[score_column] / 0.5,  # Adjust the size of the bubbles
                color=color,
                fill=True,
                fill_opacity=0.4, # Adjust transparency for the fill (0 = fully transparent, 1 = fully opaque)
                opacity=0.2,  # Adjust transparency for the circle's border (0 = fully transparent, 1 = fully opaque)
                popup=folium.Popup(f"{row['Ticker']} - {popup_label}: {row[score_column]}")
            ).add_to(esg_layer)

# Add circle markers for each ESG score
add_esg_layer(esg_layers['Environment Score'], 'Environment Score', 'green', 'Environment Score')
add_esg_layer(esg_layers['Social Score'], 'Social Score', 'blue', 'Social Score')
add_esg_layer(esg_layers['Governance Score'], 'Governance Score', 'red', 'Governance Score')

# Add the layers to the map
for layer in esg_layers.values():
    layer.add_to(company_map)

# Add layer control to toggle between the ESG layers
folium.LayerControl().add_to(company_map)

# Save the map to an HTML file and display it
company_map.save("company_map_esg.html")
company_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_95454bbc6b0124048da4432704c0b490 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_95454bbc6b0124048da4432704c0b490&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_95454bbc6b0124048da4432704c0b490 = L.map(
#                 &quot;map_95454bbc6b0124048da4432704c0b490&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_01acb7578d2595433a8e8eaa9cf57212 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_01acb7578d2595433a8e8eaa9cf57212.addTo(map_95454bbc6b0124048da4432704c0b490);
#
#
#             var feature_group_5a0fd842185a7df3cbf116a5403f7007 = L.featureGroup(
#                 {}
#             );
#
#
#             var circle_marker_803c6b7365929f630ae69ff4168559ab = L.circleMarker(
#                 [30.5085915, -97.6788056],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.2, &quot;radius&quot;: 1.42, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_5a0fd842185a7df3cbf116a5403f7007);
#
#
#         var popup_906363633a1f37fef873934df77e538f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_95b4c8e5cbddde7983ad592aa708899e = $(`&lt;div id=&quot;html_95b4c8e5cbddde7983ad592aa708899e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DELL - Environment Score: 0.71&lt;/div&gt;`)[0];
#                 popup_906363633a1f37fef873934df77e538f.setContent(html_95b4c8e5cbddde7983ad592aa708899e);
#
#
#
#         circle_marker_803c6b7365929f630ae69ff4168559ab.bindPopup(popup_906363633a1f37fef873934df77e538f)
#         ;
#
#
#
#
#             var circle_marker_0afc55141ed13fb340574cc3e5fac7f9 = L.circleMarker(
#                 [37.2333253, -121.6846349],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.2, &quot;radius&quot;: 1.4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_5a0fd842185a7df3cbf116a5403f7007);
#
#
#         var popup_f584a8eceb95ee947d62924f68cf6e53 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8d43eec5eb94aaacf9583eb4019eb825 = $(`&lt;div id=&quot;html_8d43eec5eb94aaacf9583eb4019eb825&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;PANW - Environment Score: 0.7&lt;/div&gt;`)[0];
#                 popup_f584a8eceb95ee947d62924f68cf6e53.setContent(html_8d43eec5eb94aaacf9583eb4019eb825);
#
#
#
#         circle_marker_0afc55141ed13fb340574cc3e5fac7f9.bindPopup(popup_f584a8eceb95ee947d62924f68cf6e53)
#         ;
#
#
#
#
#             var circle_marker_920cd193575e8ff8f49e48db0ed0bd58 = L.circleMarker(
#                 [41.1175966, -73.4078968],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.2, &quot;radius&quot;: 1.96, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_5a0fd842185a7df3cbf116a5403f7007);
#
#
#         var popup_dd3ef9e2f83bc1276d76ef2f1f57175f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a345001c2fd96b93b6c31bef3a723e9c = $(`&lt;div id=&quot;html_a345001c2fd96b93b6c31bef3a723e9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BKNG - Environment Score: 0.98&lt;/div&gt;`)[0];
#                 popup_dd3ef9e2f83bc1276d76ef2f1f57175f.setContent(html_a345001c2fd96b93b6c31bef3a723e9c);
#
#
#
#         circle_marker_920cd193575e8ff8f49e48db0ed0bd58.bindPopup(popup_dd3ef9e2f83bc1276d76ef2f1f57175f)
#         ;
#
#
#
#
#             var circle_marker_3de23b3b7c2d14f609d92311ffe0e21b = L.circleMarker(
#                 [41.1264847, -73.7139777],
